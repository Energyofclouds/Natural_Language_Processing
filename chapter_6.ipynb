# %%
from google.colab import drive


drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks

# %%
class LSTM:
    def __init__(self, Wx, Wh, b):
        '''

        Parameters
        ----------
        Wx: 입력 x에 대한 가중치 매개변수(4개분의 가중치가 담겨 있음)
        Wh: 은닉 상태 h에 대한 가장추 매개변수(4개분의 가중치가 담겨 있음)
        b: 편향（4개분의 편향이 담겨 있음）
        '''
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.cache = None

    def forward(self, x, h_prev, c_prev):
        Wx, Wh, b = self.params
        N, H = h_prev.shape

        A = np.dot(x, Wx) + np.dot(h_prev, Wh) + b

        f = A[:, :H]
        g = A[:, H:2*H]
        i = A[:, 2*H:3*H]
        o = A[:, 3*H:]

        f = sigmoid(f)
        g = np.tanh(g)
        i = sigmoid(i)
        o = sigmoid(o)

        c_next = f * c_prev + g * i
        h_next = o * np.tanh(c_next)

        self.cache = (x, h_prev, c_prev, i, f, g, o, c_next)
        return h_next, c_next

    def backward(self, dh_next, dc_next):
        Wx, Wh, b = self.params
        x, h_prev, c_prev, i, f, g, o, c_next = self.cache

        tanh_c_next = np.tanh(c_next)

        ds = dc_next + (dh_next * o) * (1 - tanh_c_next ** 2)

        dc_prev = ds * f

        di = ds * g
        df = ds * c_prev
        do = dh_next * tanh_c_next
        dg = ds * i

        di *= i * (1 - i)
        df *= f * (1 - f)
        do *= o * (1 - o)
        dg *= (1 - g ** 2)

        dA = np.hstack((df, dg, di, do))

        dWh = np.dot(h_prev.T, dA)
        dWx = np.dot(x.T, dA)
        db = dA.sum(axis=0)

        self.grads[0][...] = dWx
        self.grads[1][...] = dWh
        self.grads[2][...] = db

        dx = np.dot(dA, Wx.T)
        dh_prev = np.dot(dA, Wh.T)

        return dx, dh_prev, dc_prev

# %%
class TimeLSTM:
    def __init__(self, Wx, Wh, b, stateful=False):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.layers = None

        self.h, self.c = None, None
        self.dh = None
        self.stateful = stateful

    def forward(self, xs):
        Wx, Wh, b = self.params
        N, T, D = xs.shape
        H = Wh.shape[0]

        self.layers = []
        hs = np.empty((N, T, H), dtype='f')

        if not self.stateful or self.h is None:
            self.h = np.zeros((N, H), dtype='f')
        if not self.stateful or self.c is None:
            self.c = np.zeros((N, H), dtype='f')

        for t in range(T):
            layer = LSTM(*self.params)
            self.h, self.c = layer.forward(xs[:, t, :], self.h, self.c)
            hs[:, t, :] = self.h

            self.layers.append(layer)

        return hs

    def backward(self, dhs):
        Wx, Wh, b = self.params
        N, T, H = dhs.shape
        D = Wx.shape[0]

        dxs = np.empty((N, T, D), dtype='f')
        dh, dc = 0, 0

        grads = [0, 0, 0]
        for t in reversed(range(T)):
            layer = self.layers[t]
            dx, dh, dc = layer.backward(dhs[:, t, :] + dh, dc)
            dxs[:, t, :] = dx
            for i, grad in enumerate(layer.grads):
                grads[i] += grad

        for i, grad in enumerate(grads):
            self.grads[i][...] = grad
        self.dh = dh
        return dxs

    def set_state(self, h, c=None):
        self.h, self.c = h, c

    def reset_state(self):
        self.h, self.c = None, None

# %%
from common.time_layers import *
from common.base_model import BaseModel


class Rnnlm(BaseModel):
    def __init__(self, vocab_size=10000, wordvec_size=100, hidden_size=100):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        # 가중치 초기화
        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        # 계층 생성
        self.layers = [
            TimeEmbedding(embed_W),
            TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True),
            TimeAffine(affine_W, affine_b)
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layer = self.layers[1]

        # 모든 가중치와 기울기를 리스트에 모은다.
        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def predict(self, xs):
        for layer in self.layers:
            xs = layer.forward(xs)
        return xs

    def forward(self, xs, ts):
        score = self.predict(xs)
        loss = self.loss_layer.forward(score, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        self.lstm_layer.reset_state()

# %%
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity
from dataset import ptb



# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 100
hidden_size = 100  # RNN의 은닉 상태 벡터의 원소 수
time_size = 35     # RNN을 펼치는 크기
lr = 20.0
max_epoch = 4
max_grad = 0.25

# 학습 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test, _, _ = ptb.load_data('test')
vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

# 모델 생성
model = Rnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

# 기울기 클리핑을 적용하여 학습
trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad,
            eval_interval=20)
trainer.plot(ylim=(0, 500))

# 테스트 데이터로 평가
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('테스트 퍼플렉서티: ', ppl_test)

# 매개변수 저장
model.save_params()
# Out:
# | 에폭 1 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 10000.08
# | 에폭 1 |  반복 21 / 1327 | 시간 7[s] | 퍼플렉서티 2932.38
# | 에폭 1 |  반복 41 / 1327 | 시간 14[s] | 퍼플렉서티 1238.49
# | 에폭 1 |  반복 61 / 1327 | 시간 21[s] | 퍼플렉서티 954.45
# | 에폭 1 |  반복 81 / 1327 | 시간 28[s] | 퍼플렉서티 829.46
# | 에폭 1 |  반복 101 / 1327 | 시간 35[s] | 퍼플렉서티 651.51
# | 에폭 1 |  반복 121 / 1327 | 시간 42[s] | 퍼플렉서티 659.10
# | 에폭 1 |  반복 141 / 1327 | 시간 51[s] | 퍼플렉서티 584.87
# | 에폭 1 |  반복 161 / 1327 | 시간 58[s] | 퍼플렉서티 605.16
# | 에폭 1 |  반복 181 / 1327 | 시간 65[s] | 퍼플렉서티 575.65
# | 에폭 1 |  반복 201 / 1327 | 시간 72[s] | 퍼플렉서티 506.36
# | 에폭 1 |  반복 221 / 1327 | 시간 79[s] | 퍼플렉서티 497.40
# | 에폭 1 |  반복 241 / 1327 | 시간 86[s] | 퍼플렉서티 442.41
# | 에폭 1 |  반복 261 / 1327 | 시간 93[s] | 퍼플렉서티 465.74
# | 에폭 1 |  반복 281 / 1327 | 시간 100[s] | 퍼플렉서티 447.29
# | 에폭 1 |  반복 301 / 1327 | 시간 107[s] | 퍼플렉서티 391.44
# | 에폭 1 |  반복 321 / 1327 | 시간 114[s] | 퍼플렉서티 343.68
# | 에폭 1 |  반복 341 / 1327 | 시간 121[s] | 퍼플렉서티 397.32
# | 에폭 1 |  반복 361 / 1327 | 시간 128[s] | 퍼플렉서티 401.03
# | 에폭 1 |  반복 381 / 1327 | 시간 135[s] | 퍼플렉서티 333.45
# | 에폭 1 |  반복 401 / 1327 | 시간 141[s] | 퍼플렉서티 348.42
# | 에폭 1 |  반복 421 / 1327 | 시간 148[s] | 퍼플렉서티 344.42
# | 에폭 1 |  반복 441 / 1327 | 시간 155[s] | 퍼플렉서티 324.19
# | 에폭 1 |  반복 461 / 1327 | 시간 162[s] | 퍼플렉서티 327.38
# | 에폭 1 |  반복 481 / 1327 | 시간 168[s] | 퍼플렉서티 304.06
# | 에폭 1 |  반복 501 / 1327 | 시간 175[s] | 퍼플렉서티 314.33
# | 에폭 1 |  반복 521 / 1327 | 시간 182[s] | 퍼플렉서티 299.57
# | 에폭 1 |  반복 541 / 1327 | 시간 189[s] | 퍼플렉서티 316.95
# | 에폭 1 |  반복 561 / 1327 | 시간 196[s] | 퍼플렉서티 285.81
# | 에폭 1 |  반복 581 / 1327 | 시간 202[s] | 퍼플렉서티 254.95
# | 에폭 1 |  반복 601 / 1327 | 시간 209[s] | 퍼플렉서티 336.61
# | 에폭 1 |  반복 621 / 1327 | 시간 216[s] | 퍼플렉서티 306.48
# | 에폭 1 |  반복 641 / 1327 | 시간 223[s] | 퍼플렉서티 280.22
# | 에폭 1 |  반복 661 / 1327 | 시간 231[s] | 퍼플렉서티 269.14
# | 에폭 1 |  반복 681 / 1327 | 시간 238[s] | 퍼플렉서티 226.29
# | 에폭 1 |  반복 701 / 1327 | 시간 245[s] | 퍼플렉서티 248.52
# | 에폭 1 |  반복 721 / 1327 | 시간 251[s] | 퍼플렉서티 257.57
# | 에폭 1 |  반복 741 / 1327 | 시간 258[s] | 퍼플렉서티 219.58
# | 에폭 1 |  반복 761 / 1327 | 시간 265[s] | 퍼플렉서티 231.77
# | 에폭 1 |  반복 781 / 1327 | 시간 272[s] | 퍼플렉서티 217.57
# | 에폭 1 |  반복 801 / 1327 | 시간 279[s] | 퍼플렉서티 238.59
# | 에폭 1 |  반복 821 / 1327 | 시간 285[s] | 퍼플렉서티 224.02
# | 에폭 1 |  반복 841 / 1327 | 시간 292[s] | 퍼플렉서티 229.28
# | 에폭 1 |  반복 861 / 1327 | 시간 299[s] | 퍼플렉서티 222.34
# | 에폭 1 |  반복 881 / 1327 | 시간 305[s] | 퍼플렉서티 204.04
# | 에폭 1 |  반복 901 / 1327 | 시간 312[s] | 퍼플렉서티 253.30
# | 에폭 1 |  반복 921 / 1327 | 시간 319[s] | 퍼플렉서티 224.40
# | 에폭 1 |  반복 941 / 1327 | 시간 326[s] | 퍼플렉서티 227.13
# | 에폭 1 |  반복 961 / 1327 | 시간 332[s] | 퍼플렉서티 245.21
# | 에폭 1 |  반복 981 / 1327 | 시간 339[s] | 퍼플렉서티 227.86
# | 에폭 1 |  반복 1001 / 1327 | 시간 346[s] | 퍼플렉서티 194.09
# | 에폭 1 |  반복 1021 / 1327 | 시간 352[s] | 퍼플렉서티 226.00
# | 에폭 1 |  반복 1041 / 1327 | 시간 359[s] | 퍼플렉서티 207.13
# | 에폭 1 |  반복 1061 / 1327 | 시간 366[s] | 퍼플렉서티 195.35
# | 에폭 1 |  반복 1081 / 1327 | 시간 372[s] | 퍼플렉서티 169.77
# | 에폭 1 |  반복 1101 / 1327 | 시간 379[s] | 퍼플렉서티 192.79
# | 에폭 1 |  반복 1121 / 1327 | 시간 386[s] | 퍼플렉서티 228.17
# | 에폭 1 |  반복 1141 / 1327 | 시간 392[s] | 퍼플렉서티 208.12
# | 에폭 1 |  반복 1161 / 1327 | 시간 399[s] | 퍼플렉서티 197.53
# | 에폭 1 |  반복 1181 / 1327 | 시간 406[s] | 퍼플렉서티 190.19
# | 에폭 1 |  반복 1201 / 1327 | 시간 414[s] | 퍼플렉서티 161.31
# | 에폭 1 |  반복 1221 / 1327 | 시간 421[s] | 퍼플렉서티 159.61
# | 에폭 1 |  반복 1241 / 1327 | 시간 428[s] | 퍼플렉서티 187.11
# | 에폭 1 |  반복 1261 / 1327 | 시간 435[s] | 퍼플렉서티 172.25
# | 에폭 1 |  반복 1281 / 1327 | 시간 442[s] | 퍼플렉서티 178.83
# | 에폭 1 |  반복 1301 / 1327 | 시간 448[s] | 퍼플렉서티 221.45
# | 에폭 1 |  반복 1321 / 1327 | 시간 455[s] | 퍼플렉서티 210.45
# | 에폭 2 |  반복 1 / 1327 | 시간 457[s] | 퍼플렉서티 223.06
# | 에폭 2 |  반복 21 / 1327 | 시간 464[s] | 퍼플렉서티 204.54
# | 에폭 2 |  반복 41 / 1327 | 시간 471[s] | 퍼플렉서티 189.02
# | 에폭 2 |  반복 61 / 1327 | 시간 477[s] | 퍼플렉서티 175.81
# | 에폭 2 |  반복 81 / 1327 | 시간 484[s] | 퍼플렉서티 158.75
# | 에폭 2 |  반복 101 / 1327 | 시간 491[s] | 퍼플렉서티 153.54
# | 에폭 2 |  반복 121 / 1327 | 시간 498[s] | 퍼플렉서티 159.91
# | 에폭 2 |  반복 141 / 1327 | 시간 504[s] | 퍼플렉서티 177.09
# | 에폭 2 |  반복 161 / 1327 | 시간 511[s] | 퍼플렉서티 193.18
# | 에폭 2 |  반복 181 / 1327 | 시간 517[s] | 퍼플렉서티 199.82
# | 에폭 2 |  반복 201 / 1327 | 시간 524[s] | 퍼플렉서티 186.15
# | 에폭 2 |  반복 221 / 1327 | 시간 531[s] | 퍼플렉서티 185.05
# | 에폭 2 |  반복 241 / 1327 | 시간 537[s] | 퍼플렉서티 177.34
# | 에폭 2 |  반복 261 / 1327 | 시간 544[s] | 퍼플렉서티 184.80
# | 에폭 2 |  반복 281 / 1327 | 시간 551[s] | 퍼플렉서티 186.60
# | 에폭 2 |  반복 301 / 1327 | 시간 557[s] | 퍼플렉서티 166.62
# | 에폭 2 |  반복 321 / 1327 | 시간 564[s] | 퍼플렉서티 139.98
# | 에폭 2 |  반복 341 / 1327 | 시간 571[s] | 퍼플렉서티 173.72
# | 에폭 2 |  반복 361 / 1327 | 시간 577[s] | 퍼플렉서티 197.48
# | 에폭 2 |  반복 381 / 1327 | 시간 584[s] | 퍼플렉서티 152.86
# | 에폭 2 |  반복 401 / 1327 | 시간 591[s] | 퍼플렉서티 168.96
# | 에폭 2 |  반복 421 / 1327 | 시간 599[s] | 퍼플렉서티 155.65
# | 에폭 2 |  반복 441 / 1327 | 시간 606[s] | 퍼플렉서티 163.87
# | 에폭 2 |  반복 461 / 1327 | 시간 613[s] | 퍼플렉서티 157.50
# | 에폭 2 |  반복 481 / 1327 | 시간 620[s] | 퍼플렉서티 155.32
# | 에폭 2 |  반복 501 / 1327 | 시간 626[s] | 퍼플렉서티 171.11
# | 에폭 2 |  반복 521 / 1327 | 시간 633[s] | 퍼플렉서티 171.47
# | 에폭 2 |  반복 541 / 1327 | 시간 640[s] | 퍼플렉서티 174.56
# | 에폭 2 |  반복 561 / 1327 | 시간 646[s] | 퍼플렉서티 157.68
# | 에폭 2 |  반복 581 / 1327 | 시간 653[s] | 퍼플렉서티 138.87
# | 에폭 2 |  반복 601 / 1327 | 시간 660[s] | 퍼플렉서티 190.46
# | 에폭 2 |  반복 621 / 1327 | 시간 666[s] | 퍼플렉서티 181.39
# | 에폭 2 |  반복 641 / 1327 | 시간 673[s] | 퍼플렉서티 164.03
# | 에폭 2 |  반복 661 / 1327 | 시간 679[s] | 퍼플렉서티 153.66
# | 에폭 2 |  반복 681 / 1327 | 시간 686[s] | 퍼플렉서티 130.56
# | 에폭 2 |  반복 701 / 1327 | 시간 693[s] | 퍼플렉서티 151.04
# | 에폭 2 |  반복 721 / 1327 | 시간 699[s] | 퍼플렉서티 159.31
# | 에폭 2 |  반복 741 / 1327 | 시간 706[s] | 퍼플렉서티 133.31
# | 에폭 2 |  반복 761 / 1327 | 시간 713[s] | 퍼플렉서티 133.46
# | 에폭 2 |  반복 781 / 1327 | 시간 719[s] | 퍼플렉서티 135.25
# | 에폭 2 |  반복 801 / 1327 | 시간 726[s] | 퍼플렉서티 147.78
# | 에폭 2 |  반복 821 / 1327 | 시간 733[s] | 퍼플렉서티 144.75
# | 에폭 2 |  반복 841 / 1327 | 시간 739[s] | 퍼플렉서티 145.00
# | 에폭 2 |  반복 861 / 1327 | 시간 746[s] | 퍼플렉서티 146.80
# | 에폭 2 |  반복 881 / 1327 | 시간 753[s] | 퍼플렉서티 130.97
# | 에폭 2 |  반복 901 / 1327 | 시간 759[s] | 퍼플렉서티 166.58
# | 에폭 2 |  반복 921 / 1327 | 시간 766[s] | 퍼플렉서티 145.29
# | 에폭 2 |  반복 941 / 1327 | 시간 773[s] | 퍼플렉서티 153.37
# | 에폭 2 |  반복 961 / 1327 | 시간 779[s] | 퍼플렉서티 164.61
# | 에폭 2 |  반복 981 / 1327 | 시간 788[s] | 퍼플렉서티 154.61
# | 에폭 2 |  반복 1001 / 1327 | 시간 795[s] | 퍼플렉서티 131.89
# | 에폭 2 |  반복 1021 / 1327 | 시간 801[s] | 퍼플렉서티 157.08
# | 에폭 2 |  반복 1041 / 1327 | 시간 808[s] | 퍼플렉서티 143.90
# | 에폭 2 |  반복 1061 / 1327 | 시간 815[s] | 퍼플렉서티 128.32
# | 에폭 2 |  반복 1081 / 1327 | 시간 821[s] | 퍼플렉서티 111.71
# | 에폭 2 |  반복 1101 / 1327 | 시간 828[s] | 퍼플렉서티 121.99
# | 에폭 2 |  반복 1121 / 1327 | 시간 834[s] | 퍼플렉서티 155.20
# | 에폭 2 |  반복 1141 / 1327 | 시간 841[s] | 퍼플렉서티 142.03
# | 에폭 2 |  반복 1161 / 1327 | 시간 848[s] | 퍼플렉서티 133.00
# | 에폭 2 |  반복 1181 / 1327 | 시간 855[s] | 퍼플렉서티 134.49
# | 에폭 2 |  반복 1201 / 1327 | 시간 862[s] | 퍼플렉서티 112.15
# | 에폭 2 |  반복 1221 / 1327 | 시간 868[s] | 퍼플렉서티 110.62
# | 에폭 2 |  반복 1241 / 1327 | 시간 875[s] | 퍼플렉서티 130.31
# | 에폭 2 |  반복 1261 / 1327 | 시간 882[s] | 퍼플렉서티 124.51
# | 에폭 2 |  반복 1281 / 1327 | 시간 889[s] | 퍼플렉서티 122.91
# | 에폭 2 |  반복 1301 / 1327 | 시간 895[s] | 퍼플렉서티 156.73
# | 에폭 2 |  반복 1321 / 1327 | 시간 902[s] | 퍼플렉서티 153.22
# | 에폭 3 |  반복 1 / 1327 | 시간 904[s] | 퍼플렉서티 160.26
# | 에폭 3 |  반복 21 / 1327 | 시간 911[s] | 퍼플렉서티 144.53
# | 에폭 3 |  반복 41 / 1327 | 시간 918[s] | 퍼플렉서티 135.39
# | 에폭 3 |  반복 61 / 1327 | 시간 924[s] | 퍼플렉서티 127.10
# | 에폭 3 |  반복 81 / 1327 | 시간 931[s] | 퍼플렉서티 116.51
# | 에폭 3 |  반복 101 / 1327 | 시간 938[s] | 퍼플렉서티 107.61
# | 에폭 3 |  반복 121 / 1327 | 시간 944[s] | 퍼플렉서티 115.24
# | 에폭 3 |  반복 141 / 1327 | 시간 951[s] | 퍼플렉서티 124.98
# | 에폭 3 |  반복 161 / 1327 | 시간 957[s] | 퍼플렉서티 142.92
# | 에폭 3 |  반복 181 / 1327 | 시간 964[s] | 퍼플렉서티 150.28
# | 에폭 3 |  반복 201 / 1327 | 시간 973[s] | 퍼플렉서티 140.95
# | 에폭 3 |  반복 221 / 1327 | 시간 979[s] | 퍼플렉서티 140.91
# | 에폭 3 |  반복 241 / 1327 | 시간 986[s] | 퍼플렉서티 133.63
# | 에폭 3 |  반복 261 / 1327 | 시간 993[s] | 퍼플렉서티 138.03
# | 에폭 3 |  반복 281 / 1327 | 시간 999[s] | 퍼플렉서티 143.61
# | 에폭 3 |  반복 301 / 1327 | 시간 1006[s] | 퍼플렉서티 124.40
# | 에폭 3 |  반복 321 / 1327 | 시간 1013[s] | 퍼플렉서티 100.98
# | 에폭 3 |  반복 341 / 1327 | 시간 1019[s] | 퍼플렉서티 125.03
# | 에폭 3 |  반복 361 / 1327 | 시간 1026[s] | 퍼플렉서티 151.76
# | 에폭 3 |  반복 381 / 1327 | 시간 1033[s] | 퍼플렉서티 115.56
# | 에폭 3 |  반복 401 / 1327 | 시간 1039[s] | 퍼플렉서티 130.76
# | 에폭 3 |  반복 421 / 1327 | 시간 1046[s] | 퍼플렉서티 113.33
# | 에폭 3 |  반복 441 / 1327 | 시간 1053[s] | 퍼플렉서티 124.33
# | 에폭 3 |  반복 461 / 1327 | 시간 1059[s] | 퍼플렉서티 117.28
# | 에폭 3 |  반복 481 / 1327 | 시간 1066[s] | 퍼플렉서티 119.74
# | 에폭 3 |  반복 501 / 1327 | 시간 1073[s] | 퍼플렉서티 129.63
# | 에폭 3 |  반복 521 / 1327 | 시간 1079[s] | 퍼플렉서티 136.40
# | 에폭 3 |  반복 541 / 1327 | 시간 1086[s] | 퍼플렉서티 136.37
# | 에폭 3 |  반복 561 / 1327 | 시간 1093[s] | 퍼플렉서티 119.99
# | 에폭 3 |  반복 581 / 1327 | 시간 1099[s] | 퍼플렉서티 106.29
# | 에폭 3 |  반복 601 / 1327 | 시간 1106[s] | 퍼플렉서티 149.46
# | 에폭 3 |  반복 621 / 1327 | 시간 1113[s] | 퍼플렉서티 142.51
# | 에폭 3 |  반복 641 / 1327 | 시간 1119[s] | 퍼플렉서티 128.66
# | 에폭 3 |  반복 661 / 1327 | 시간 1126[s] | 퍼플렉서티 119.88
# | 에폭 3 |  반복 681 / 1327 | 시간 1132[s] | 퍼플렉서티 99.61
# | 에폭 3 |  반복 701 / 1327 | 시간 1139[s] | 퍼플렉서티 118.84
# | 에폭 3 |  반복 721 / 1327 | 시간 1146[s] | 퍼플렉서티 125.92
# | 에폭 3 |  반복 741 / 1327 | 시간 1154[s] | 퍼플렉서티 107.67
# | 에폭 3 |  반복 761 / 1327 | 시간 1161[s] | 퍼플렉서티 103.08
# | 에폭 3 |  반복 781 / 1327 | 시간 1168[s] | 퍼플렉서티 105.50
# | 에폭 3 |  반복 801 / 1327 | 시간 1174[s] | 퍼플렉서티 115.64
# | 에폭 3 |  반복 821 / 1327 | 시간 1181[s] | 퍼플렉서티 117.47
# | 에폭 3 |  반복 841 / 1327 | 시간 1188[s] | 퍼플렉서티 115.19
# | 에폭 3 |  반복 861 / 1327 | 시간 1195[s] | 퍼플렉서티 120.66
# | 에폭 3 |  반복 881 / 1327 | 시간 1201[s] | 퍼플렉서티 106.60
# | 에폭 3 |  반복 901 / 1327 | 시간 1208[s] | 퍼플렉서티 132.46
# | 에폭 3 |  반복 921 / 1327 | 시간 1215[s] | 퍼플렉서티 117.61
# | 에폭 3 |  반복 941 / 1327 | 시간 1221[s] | 퍼플렉서티 125.99
# | 에폭 3 |  반복 961 / 1327 | 시간 1228[s] | 퍼플렉서티 131.82
# | 에폭 3 |  반복 981 / 1327 | 시간 1234[s] | 퍼플렉서티 123.99
# | 에폭 3 |  반복 1001 / 1327 | 시간 1241[s] | 퍼플렉서티 109.48
# | 에폭 3 |  반복 1021 / 1327 | 시간 1248[s] | 퍼플렉서티 129.53
# | 에폭 3 |  반복 1041 / 1327 | 시간 1254[s] | 퍼플렉서티 119.32
# | 에폭 3 |  반복 1061 / 1327 | 시간 1261[s] | 퍼플렉서티 102.17
# | 에폭 3 |  반복 1081 / 1327 | 시간 1268[s] | 퍼플렉서티 89.38
# | 에폭 3 |  반복 1101 / 1327 | 시간 1274[s] | 퍼플렉서티 95.74
# | 에폭 3 |  반복 1121 / 1327 | 시간 1281[s] | 퍼플렉서티 122.32
# | 에폭 3 |  반복 1141 / 1327 | 시간 1288[s] | 퍼플렉서티 113.66
# | 에폭 3 |  반복 1161 / 1327 | 시간 1295[s] | 퍼플렉서티 105.18
# | 에폭 3 |  반복 1181 / 1327 | 시간 1301[s] | 퍼플렉서티 111.29
# | 에폭 3 |  반복 1201 / 1327 | 시간 1308[s] | 퍼플렉서티 93.58
# | 에폭 3 |  반복 1221 / 1327 | 시간 1314[s] | 퍼플렉서티 88.78
# | 에폭 3 |  반복 1241 / 1327 | 시간 1321[s] | 퍼플렉서티 105.44
# | 에폭 3 |  반복 1261 / 1327 | 시간 1328[s] | 퍼플렉서티 104.30
# | 에폭 3 |  반복 1281 / 1327 | 시간 1335[s] | 퍼플렉서티 100.78
# | 에폭 3 |  반복 1301 / 1327 | 시간 1343[s] | 퍼플렉서티 128.21
# | 에폭 3 |  반복 1321 / 1327 | 시간 1350[s] | 퍼플렉서티 126.21
# | 에폭 4 |  반복 1 / 1327 | 시간 1352[s] | 퍼플렉서티 132.01
# | 에폭 4 |  반복 21 / 1327 | 시간 1359[s] | 퍼플렉서티 122.28
# | 에폭 4 |  반복 41 / 1327 | 시간 1365[s] | 퍼플렉서티 107.54
# | 에폭 4 |  반복 61 / 1327 | 시간 1372[s] | 퍼플렉서티 106.38
# | 에폭 4 |  반복 81 / 1327 | 시간 1379[s] | 퍼플렉서티 95.91
# | 에폭 4 |  반복 101 / 1327 | 시간 1385[s] | 퍼플렉서티 87.34
# | 에폭 4 |  반복 121 / 1327 | 시간 1392[s] | 퍼플렉서티 94.80
# | 에폭 4 |  반복 141 / 1327 | 시간 1399[s] | 퍼플렉서티 103.23
# | 에폭 4 |  반복 161 / 1327 | 시간 1406[s] | 퍼플렉서티 118.09
# | 에폭 4 |  반복 181 / 1327 | 시간 1412[s] | 퍼플렉서티 128.12
# | 에폭 4 |  반복 201 / 1327 | 시간 1419[s] | 퍼플렉서티 119.27
# | 에폭 4 |  반복 221 / 1327 | 시간 1425[s] | 퍼플렉서티 122.69
# | 에폭 4 |  반복 241 / 1327 | 시간 1432[s] | 퍼플렉서티 113.52
# | 에폭 4 |  반복 261 / 1327 | 시간 1438[s] | 퍼플렉서티 114.09
# | 에폭 4 |  반복 281 / 1327 | 시간 1445[s] | 퍼플렉서티 122.03
# | 에폭 4 |  반복 301 / 1327 | 시간 1452[s] | 퍼플렉서티 103.36
# | 에폭 4 |  반복 321 / 1327 | 시간 1459[s] | 퍼플렉서티 83.99
# | 에폭 4 |  반복 341 / 1327 | 시간 1465[s] | 퍼플렉서티 101.09
# | 에폭 4 |  반복 361 / 1327 | 시간 1472[s] | 퍼플렉서티 127.16
# | 에폭 4 |  반복 381 / 1327 | 시간 1478[s] | 퍼플렉서티 98.31
# | 에폭 4 |  반복 401 / 1327 | 시간 1485[s] | 퍼플렉서티 111.39
# | 에폭 4 |  반복 421 / 1327 | 시간 1492[s] | 퍼플렉서티 94.69
# | 에폭 4 |  반복 441 / 1327 | 시간 1498[s] | 퍼플렉서티 103.68
# | 에폭 4 |  반복 461 / 1327 | 시간 1505[s] | 퍼플렉서티 99.15
# | 에폭 4 |  반복 481 / 1327 | 시간 1512[s] | 퍼플렉서티 102.70
# | 에폭 4 |  반복 501 / 1327 | 시간 1519[s] | 퍼플렉서티 109.58
# | 에폭 4 |  반복 521 / 1327 | 시간 1527[s] | 퍼플렉서티 115.98
# | 에폭 4 |  반복 541 / 1327 | 시간 1534[s] | 퍼플렉서티 113.55
# | 에폭 4 |  반복 561 / 1327 | 시간 1541[s] | 퍼플렉서티 103.76
# | 에폭 4 |  반복 581 / 1327 | 시간 1547[s] | 퍼플렉서티 89.16
# | 에폭 4 |  반복 601 / 1327 | 시간 1554[s] | 퍼플렉서티 127.24
# | 에폭 4 |  반복 621 / 1327 | 시간 1560[s] | 퍼플렉서티 121.34
# | 에폭 4 |  반복 641 / 1327 | 시간 1567[s] | 퍼플렉서티 110.71
# | 에폭 4 |  반복 661 / 1327 | 시간 1574[s] | 퍼플렉서티 102.93
# | 에폭 4 |  반복 681 / 1327 | 시간 1580[s] | 퍼플렉서티 85.13
# | 에폭 4 |  반복 701 / 1327 | 시간 1587[s] | 퍼플렉서티 101.54
# | 에폭 4 |  반복 721 / 1327 | 시간 1594[s] | 퍼플렉서티 106.69
# | 에폭 4 |  반복 741 / 1327 | 시간 1600[s] | 퍼플렉서티 95.30
# | 에폭 4 |  반복 761 / 1327 | 시간 1607[s] | 퍼플렉서티 88.70
# | 에폭 4 |  반복 781 / 1327 | 시간 1614[s] | 퍼플렉서티 88.35
# | 에폭 4 |  반복 801 / 1327 | 시간 1621[s] | 퍼플렉서티 97.83
# | 에폭 4 |  반복 821 / 1327 | 시간 1627[s] | 퍼플렉서티 102.76
# | 에폭 4 |  반복 841 / 1327 | 시간 1634[s] | 퍼플렉서티 98.77
# | 에폭 4 |  반복 861 / 1327 | 시간 1641[s] | 퍼플렉서티 105.05
# | 에폭 4 |  반복 881 / 1327 | 시간 1647[s] | 퍼플렉서티 91.50
# | 에폭 4 |  반복 901 / 1327 | 시간 1654[s] | 퍼플렉서티 115.60
# | 에폭 4 |  반복 921 / 1327 | 시간 1661[s] | 퍼플렉서티 103.22
# | 에폭 4 |  반복 941 / 1327 | 시간 1668[s] | 퍼플렉서티 112.14
# | 에폭 4 |  반복 961 / 1327 | 시간 1674[s] | 퍼플렉서티 113.00
# | 에폭 4 |  반복 981 / 1327 | 시간 1681[s] | 퍼플렉서티 106.41
# | 에폭 4 |  반복 1001 / 1327 | 시간 1688[s] | 퍼플렉서티 97.34
# | 에폭 4 |  반복 1021 / 1327 | 시간 1694[s] | 퍼플렉서티 113.05
# | 에폭 4 |  반복 1041 / 1327 | 시간 1701[s] | 퍼플렉서티 103.99
# | 에폭 4 |  반복 1061 / 1327 | 시간 1710[s] | 퍼플렉서티 88.80
# | 에폭 4 |  반복 1081 / 1327 | 시간 1716[s] | 퍼플렉서티 79.82
# | 에폭 4 |  반복 1101 / 1327 | 시간 1723[s] | 퍼플렉서티 79.45
# | 에폭 4 |  반복 1121 / 1327 | 시간 1730[s] | 퍼플렉서티 103.31
# | 에폭 4 |  반복 1141 / 1327 | 시간 1736[s] | 퍼플렉서티 98.97
# | 에폭 4 |  반복 1161 / 1327 | 시간 1743[s] | 퍼플렉서티 90.98
# | 에폭 4 |  반복 1181 / 1327 | 시간 1750[s] | 퍼플렉서티 95.70
# | 에폭 4 |  반복 1201 / 1327 | 시간 1756[s] | 퍼플렉서티 82.60
# | 에폭 4 |  반복 1221 / 1327 | 시간 1763[s] | 퍼플렉서티 76.04
# | 에폭 4 |  반복 1241 / 1327 | 시간 1770[s] | 퍼플렉서티 90.96
# | 에폭 4 |  반복 1261 / 1327 | 시간 1776[s] | 퍼플렉서티 93.55
# | 에폭 4 |  반복 1281 / 1327 | 시간 1783[s] | 퍼플렉서티 89.67
# | 에폭 4 |  반복 1301 / 1327 | 시간 1790[s] | 퍼플렉서티 110.52
# | 에폭 4 |  반복 1321 / 1327 | 시간 1796[s] | 퍼플렉서티 108.95
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48373 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47113 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48373 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54140 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47113 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# 퍼플렉서티 평가 중 ...
# 234 / 235
# 테스트 퍼플렉서티:  133.45997831843582

# %%
from common.time_layers import *
from common.np import *  # import numpy as np
from common.base_model import BaseModel


class BetterRnnlm(BaseModel):
    
    def __init__(self, vocab_size=10000, wordvec_size=650,
                 hidden_size=650, dropout_ratio=0.5):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx1 = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh1 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b1 = np.zeros(4 * H).astype('f')
        lstm_Wx2 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_Wh2 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b2 = np.zeros(4 * H).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.layers = [
            TimeEmbedding(embed_W),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx1, lstm_Wh1, lstm_b1, stateful=True),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx2, lstm_Wh2, lstm_b2, stateful=True),
            TimeDropout(dropout_ratio),
            TimeAffine(embed_W.T, affine_b)  # weight tying!!
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layers = [self.layers[2], self.layers[4]]
        self.drop_layers = [self.layers[1], self.layers[3], self.layers[5]]

        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def predict(self, xs, train_flg=False):
        for layer in self.drop_layers:
            layer.train_flg = train_flg

        for layer in self.layers:
            xs = layer.forward(xs)
        return xs

    def forward(self, xs, ts, train_flg=True):
        score = self.predict(xs, train_flg)
        loss = self.loss_layer.forward(score, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        for layer in self.lstm_layers:
            layer.reset_state()

# %%
from common import config
# GPU에서 실행하려면 아래 주석을 해제하세요(CuPy 필요).
# ==============================================
# config.GPU = True
# ==============================================
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity, to_gpu
from dataset import ptb

# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 650
hidden_size = 650
time_size = 35
lr = 20.0
max_epoch = 4
max_grad = 0.25
dropout = 0.5

# 학습 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_val, _, _ = ptb.load_data('val')
corpus_test, _, _ = ptb.load_data('test')

if config.GPU:
    corpus = to_gpu(corpus)
    corpus_val = to_gpu(corpus_val)
    corpus_test = to_gpu(corpus_test)

vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

model = BetterRnnlm(vocab_size, wordvec_size, hidden_size, dropout)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

best_ppl = float('inf')
for epoch in range(max_epoch):
    trainer.fit(xs, ts, max_epoch=1, batch_size=batch_size,
                time_size=time_size, max_grad=max_grad)

    model.reset_state()
    ppl = eval_perplexity(model, corpus_val)
    print('검증 퍼플렉서티: ', ppl)

    if best_ppl > ppl:
        best_ppl = ppl
        model.save_params()
    else:
        lr /= 4.0
        optimizer.lr = lr

    model.reset_state()
    print('-' * 50)


# 테스트 데이터로 평가
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('테스트 퍼플렉서티: ', ppl_test)
# Out:
# | 에폭 1 |  반복 1 / 1327 | 시간 3[s] | 퍼플렉서티 10000.66
# | 에폭 1 |  반복 21 / 1327 | 시간 74[s] | 퍼플렉서티 5093.97
# | 에폭 1 |  반복 41 / 1327 | 시간 144[s] | 퍼플렉서티 1708.67
# | 에폭 1 |  반복 61 / 1327 | 시간 214[s] | 퍼플렉서티 1294.75
# | 에폭 1 |  반복 81 / 1327 | 시간 283[s] | 퍼플렉서티 1029.27
# | 에폭 1 |  반복 101 / 1327 | 시간 353[s] | 퍼플렉서티 891.56
# | 에폭 1 |  반복 121 / 1327 | 시간 422[s] | 퍼플렉서티 819.80
# | 에폭 1 |  반복 141 / 1327 | 시간 492[s] | 퍼플렉서티 727.03
# | 에폭 1 |  반복 161 / 1327 | 시간 561[s] | 퍼플렉서티 708.30
# | 에폭 1 |  반복 181 / 1327 | 시간 630[s] | 퍼플렉서티 679.26
# | 에폭 1 |  반복 201 / 1327 | 시간 700[s] | 퍼플렉서티 607.55
# | 에폭 1 |  반복 221 / 1327 | 시간 770[s] | 퍼플렉서티 588.70
# | 에폭 1 |  반복 241 / 1327 | 시간 840[s] | 퍼플렉서티 536.18
# | 에폭 1 |  반복 261 / 1327 | 시간 915[s] | 퍼플렉서티 544.15
# | 에폭 1 |  반복 281 / 1327 | 시간 986[s] | 퍼플렉서티 523.70
# | 에폭 1 |  반복 301 / 1327 | 시간 1057[s] | 퍼플렉서티 452.26
# | 에폭 1 |  반복 321 / 1327 | 시간 1128[s] | 퍼플렉서티 409.41
# | 에폭 1 |  반복 341 / 1327 | 시간 1200[s] | 퍼플렉서티 452.38
# | 에폭 1 |  반복 361 / 1327 | 시간 1271[s] | 퍼플렉서티 473.54
# | 에폭 1 |  반복 381 / 1327 | 시간 1342[s] | 퍼플렉서티 390.33
# | 에폭 1 |  반복 401 / 1327 | 시간 1413[s] | 퍼플렉서티 408.68
# | 에폭 1 |  반복 421 / 1327 | 시간 1484[s] | 퍼플렉서티 396.56
# | 에폭 1 |  반복 441 / 1327 | 시간 1555[s] | 퍼플렉서티 384.58
# | 에폭 1 |  반복 461 / 1327 | 시간 1626[s] | 퍼플렉서티 373.54
# | 에폭 1 |  반복 481 / 1327 | 시간 1697[s] | 퍼플렉서티 353.83
# | 에폭 1 |  반복 501 / 1327 | 시간 1768[s] | 퍼플렉서티 361.95
# | 에폭 1 |  반복 521 / 1327 | 시간 1840[s] | 퍼플렉서티 345.18
# | 에폭 1 |  반복 541 / 1327 | 시간 1911[s] | 퍼플렉서티 366.01
# | 에폭 1 |  반복 561 / 1327 | 시간 1982[s] | 퍼플렉서티 322.84
# | 에폭 1 |  반복 581 / 1327 | 시간 2054[s] | 퍼플렉서티 295.78
# | 에폭 1 |  반복 601 / 1327 | 시간 2125[s] | 퍼플렉서티 382.52
# | 에폭 1 |  반복 621 / 1327 | 시간 2196[s] | 퍼플렉서티 350.63
# | 에폭 1 |  반복 641 / 1327 | 시간 2268[s] | 퍼플렉서티 318.03
# | 에폭 1 |  반복 661 / 1327 | 시간 2339[s] | 퍼플렉서티 305.72
# | 에폭 1 |  반복 681 / 1327 | 시간 2410[s] | 퍼플렉서티 256.99
# | 에폭 1 |  반복 701 / 1327 | 시간 2481[s] | 퍼플렉서티 280.16
# | 에폭 1 |  반복 721 / 1327 | 시간 2553[s] | 퍼플렉서티 292.15
# | 에폭 1 |  반복 741 / 1327 | 시간 2624[s] | 퍼플렉서티 250.12
# | 에폭 1 |  반복 761 / 1327 | 시간 2695[s] | 퍼플렉서티 260.67
# | 에폭 1 |  반복 781 / 1327 | 시간 2766[s] | 퍼플렉서티 245.29
# | 에폭 1 |  반복 801 / 1327 | 시간 2837[s] | 퍼플렉서티 270.30
# | 에폭 1 |  반복 821 / 1327 | 시간 2908[s] | 퍼플렉서티 251.24
# | 에폭 1 |  반복 841 / 1327 | 시간 2980[s] | 퍼플렉서티 256.91
# | 에폭 1 |  반복 861 / 1327 | 시간 3052[s] | 퍼플렉서티 251.61
# | 에폭 1 |  반복 881 / 1327 | 시간 3123[s] | 퍼플렉서티 232.84
# | 에폭 1 |  반복 901 / 1327 | 시간 3194[s] | 퍼플렉서티 284.14
# | 에폭 1 |  반복 921 / 1327 | 시간 3265[s] | 퍼플렉서티 256.27
# | 에폭 1 |  반복 941 / 1327 | 시간 3335[s] | 퍼플렉서티 256.89
# | 에폭 1 |  반복 961 / 1327 | 시간 3406[s] | 퍼플렉서티 275.79
# | 에폭 1 |  반복 981 / 1327 | 시간 3477[s] | 퍼플렉서티 257.08
# | 에폭 1 |  반복 1001 / 1327 | 시간 3548[s] | 퍼플렉서티 216.50
# | 에폭 1 |  반복 1021 / 1327 | 시간 3620[s] | 퍼플렉서티 253.71
# | 에폭 1 |  반복 1041 / 1327 | 시간 3691[s] | 퍼플렉서티 232.33
# | 에폭 1 |  반복 1061 / 1327 | 시간 3763[s] | 퍼플렉서티 218.48
# | 에폭 1 |  반복 1081 / 1327 | 시간 3834[s] | 퍼플렉서티 190.77
# | 에폭 1 |  반복 1101 / 1327 | 시간 3908[s] | 퍼플렉서티 214.74
# | 에폭 1 |  반복 1121 / 1327 | 시간 3980[s] | 퍼플렉서티 258.03
# | 에폭 1 |  반복 1141 / 1327 | 시간 4051[s] | 퍼플렉서티 233.13
# | 에폭 1 |  반복 1161 / 1327 | 시간 4122[s] | 퍼플렉서티 221.73
# | 에폭 1 |  반복 1181 / 1327 | 시간 4193[s] | 퍼플렉서티 210.84
# | 에폭 1 |  반복 1201 / 1327 | 시간 4264[s] | 퍼플렉서티 182.51
# | 에폭 1 |  반복 1221 / 1327 | 시간 4335[s] | 퍼플렉서티 180.20
# | 에폭 1 |  반복 1241 / 1327 | 시간 4407[s] | 퍼플렉서티 210.92
# | 에폭 1 |  반복 1261 / 1327 | 시간 4478[s] | 퍼플렉서티 191.30
# | 에폭 1 |  반복 1281 / 1327 | 시간 4550[s] | 퍼플렉서티 199.01
# | 에폭 1 |  반복 1301 / 1327 | 시간 4620[s] | 퍼플렉서티 246.68
# | 에폭 1 |  반복 1321 / 1327 | 시간 4691[s] | 퍼플렉서티 233.23
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  200.0797701001824
# --------------------------------------------------
# | 에폭 2 |  반복 1 / 1327 | 시간 3[s] | 퍼플렉서티 302.56
# | 에폭 2 |  반복 21 / 1327 | 시간 74[s] | 퍼플렉서티 228.78
# | 에폭 2 |  반복 41 / 1327 | 시간 145[s] | 퍼플렉서티 213.12
# | 에폭 2 |  반복 61 / 1327 | 시간 216[s] | 퍼플렉서티 197.80
# | 에폭 2 |  반복 81 / 1327 | 시간 288[s] | 퍼플렉서티 179.44
# | 에폭 2 |  반복 101 / 1327 | 시간 359[s] | 퍼플렉서티 169.79
# | 에폭 2 |  반복 121 / 1327 | 시간 430[s] | 퍼플렉서티 181.48
# | 에폭 2 |  반복 141 / 1327 | 시간 501[s] | 퍼플렉서티 201.18
# | 에폭 2 |  반복 161 / 1327 | 시간 572[s] | 퍼플렉서티 216.24
# | 에폭 2 |  반복 181 / 1327 | 시간 643[s] | 퍼플렉서티 223.47
# | 에폭 2 |  반복 201 / 1327 | 시간 716[s] | 퍼플렉서티 207.25
# | 에폭 2 |  반복 221 / 1327 | 시간 788[s] | 퍼플렉서티 204.99
# | 에폭 2 |  반복 241 / 1327 | 시간 860[s] | 퍼플렉서티 196.66
# | 에폭 2 |  반복 261 / 1327 | 시간 931[s] | 퍼플렉서티 213.68
# | 에폭 2 |  반복 281 / 1327 | 시간 1003[s] | 퍼플렉서티 207.15
# | 에폭 2 |  반복 301 / 1327 | 시간 1074[s] | 퍼플렉서티 188.09
# | 에폭 2 |  반복 321 / 1327 | 시간 1146[s] | 퍼플렉서티 155.19
# | 에폭 2 |  반복 341 / 1327 | 시간 1218[s] | 퍼플렉서티 199.56
# | 에폭 2 |  반복 361 / 1327 | 시간 1289[s] | 퍼플렉서티 216.79
# | 에폭 2 |  반복 381 / 1327 | 시간 1360[s] | 퍼플렉서티 174.22
# | 에폭 2 |  반복 401 / 1327 | 시간 1431[s] | 퍼플렉서티 194.21
# | 에폭 2 |  반복 421 / 1327 | 시간 1502[s] | 퍼플렉서티 178.02
# | 에폭 2 |  반복 441 / 1327 | 시간 1573[s] | 퍼플렉서티 182.79
# | 에폭 2 |  반복 461 / 1327 | 시간 1643[s] | 퍼플렉서티 184.86
# | 에폭 2 |  반복 481 / 1327 | 시간 1713[s] | 퍼플렉서티 175.86
# | 에폭 2 |  반복 501 / 1327 | 시간 1783[s] | 퍼플렉서티 193.44
# | 에폭 2 |  반복 521 / 1327 | 시간 1852[s] | 퍼플렉서티 192.51
# | 에폭 2 |  반복 541 / 1327 | 시간 1922[s] | 퍼플렉서티 202.61
# | 에폭 2 |  반복 561 / 1327 | 시간 1992[s] | 퍼플렉서티 173.50
# | 에폭 2 |  반복 581 / 1327 | 시간 2062[s] | 퍼플렉서티 158.92
# | 에폭 2 |  반복 601 / 1327 | 시간 2132[s] | 퍼플렉서티 217.29
# | 에폭 2 |  반복 621 / 1327 | 시간 2202[s] | 퍼플렉서티 202.51
